# %%
import numpy as np
import cv2
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.layers import Conv2D, Flatten, MaxPooling2D,Dense,Dropout,SpatialDropout2D
from keras.models  import Sequential
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img, array_to_img
import random,os,glob
import matplotlib.pyplot as plt

# %%
dir_path = 'D:/EDI_SDP/Garbage classification/Garbage classification'

# %%
img_list = glob.glob(os.path.join(dir_path, '*/*.jpg'))

# %%
len(img_list)
# Out:
# 2527

# %%
train=ImageDataGenerator(horizontal_flip=True,
                         vertical_flip=True,
                         validation_split=0.1,
                         rescale=1./255,
                         shear_range = 0.1,
                         zoom_range = 0.1,
                         width_shift_range = 0.1,
                         height_shift_range = 0.1,)

test=ImageDataGenerator(rescale=1/255,
                        validation_split=0.1)

train_generator=train.flow_from_directory(dir_path,
                                          target_size=(300,300),
                                          batch_size=32,
                                          class_mode='categorical',
                                          subset='training')

test_generator=test.flow_from_directory(dir_path,
                                        target_size=(300,300),
                                        batch_size=32,
                                        class_mode='categorical',
                                        subset='validation')

labels = (train_generator.class_indices)
print(labels)

labels = dict((v,k) for k,v in labels.items())
print(labels)
# Out:
# Found 2276 images belonging to 6 classes.
# Found 251 images belonging to 6 classes.
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %%
for image_batch, label_batch in train_generator:
  break
image_batch.shape, label_batch.shape
# Out:
# ((32, 300, 300, 3), (32, 6))

# %%
print (train_generator.class_indices)

Labels = '\n'.join(sorted(train_generator.class_indices.keys()))

with open('labels.txt', 'w') as f:
  f.write(Labels)
# Out:
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}

# %%
model=Sequential()
#Convolution blocks

model.add(Conv2D(32,(3,3), padding='same',input_shape=(300,300,3),activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 


model.add(Conv2D(64,(3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 


model.add(Conv2D(32,(3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 

#Classification layers
model.add(Flatten())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32,activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(6,activation='softmax'))

filepath="trained_model.h5"
checkpoint1 = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint1]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 300, 300, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 150, 150, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 32)        18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 43808)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2803776
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 2,843,910
# Trainable params: 2,843,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])

# %%
history = model.fit_generator(train_generator,
                              epochs=100,
                              steps_per_epoch=2276//32,
                              validation_data=test_generator,
                              validation_steps=251//32,
                              workers = 4,
                              callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From <ipython-input-11-c26c4a431e4d>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 71/71 [==============================] - ETA: 0s - loss: 1.7065 - acc: 0.2888
# Epoch 00001: val_acc improved from -inf to 0.33482, saving model to trained_model.h5
# 71/71 [==============================] - 487s 7s/step - loss: 1.7065 - acc: 0.2888 - val_loss: 1.5193 - val_acc: 0.3348
# Epoch 2/100
# 71/71 [==============================] - ETA: 0s - loss: 1.5179 - acc: 0.3725
# Epoch 00002: val_acc improved from 0.33482 to 0.39286, saving model to trained_model.h5
# 71/71 [==============================] - 499s 7s/step - loss: 1.5179 - acc: 0.3725 - val_loss: 1.4242 - val_acc: 0.3929
# Epoch 3/100
# 71/71 [==============================] - ETA: 0s - loss: 1.4463 - acc: 0.3975
# Epoch 00003: val_acc improved from 0.39286 to 0.39732, saving model to trained_model.h5
100
# 71/71 [==============================] - ETA: 0s - loss: 0.5576 - acc: 0.8070
# Epoch 00070: val_acc did not improve from 0.75000
# 71/71 [==============================] - 208s 3s/step - loss: 0.5576 - acc: 0.8070 - val_loss: 0.7224 - val_acc: 0.7188
# Epoch 71/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5497 - acc: 0.8097
# Epoch 00071: val_acc did not improve from 0.75000
# 71/71 [==============================] - 207s 3s/step - loss: 0.5497 - acc: 0.8097 - val_loss: 0.8289 - val_acc: 0.7455
# Epoch 72/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5665 - acc: 0.7955
# Epoch 00072: val_acc did not improve from 0.75000
# 71/71 [==============================] - 205s 3s/step - loss: 0.5665 - acc: 0.7955 - val_loss: 0.7537 - val_acc: 0.7188
# Epoch 73/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5908 - acc: 0.7946
# Epoch 00073: val_acc did not improve from 0.75000
# 71/71 [==============================] - 206s 3s/step - loss: 0.5908 - acc: 0.7946 - val_loss: 0.7744 - val_acc: 0.6964
# Epoch 74/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5306 - acc: 0.8155
# Epoch 00074: val_acc did not improve from 0.75000
# 71/71 [==============================] - 208s 3s/step - loss: 0.5306 - acc: 0.8155 - val_loss: 0.8385 - val_acc: 0.7411
# Epoch 75/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5299 - acc: 0.8155
# Epoch 00075: val_acc did not improve from 0.75000
# 71/71 [==============================] - 205s 3s/step - loss: 0.5299 - acc: 0.8155 - val_loss: 0.8360 - val_acc: 0.7098
# Epoch 76/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5115 - acc: 0.8200
# Epoch 00076: val_acc did not improve from 0.75000
# 71/71 [==============================] - 206s 3s/step - loss: 0.5115 - acc: 0.8200 - val_loss: 0.8299 - val_acc: 0.7232
# Epoch 77/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5175 - acc: 0.8249
# Epoch 00077: val_acc did not improve from 0.75000
# 71/71 [==============================] - 201s 3s/step - loss: 0.5175 - acc: 0.8249 - val_loss: 0.9157 - val_acc: 0.7054
# Epoch 78/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5077 - acc: 0.8217
# Epoch 00078: val_acc did not improve from 0.75000
# 71/71 [==============================] - 211s 3s/step - loss: 0.5077 - acc: 0.8217 - val_loss: 0.8041 - val_acc: 0.7098
# Epoch 79/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5182 - acc: 0.8195
# Epoch 00079: val_acc did not improve from 0.75000
# 71/71 [==============================] - 201s 3s/step - loss: 0.5182 - acc: 0.8195 - val_loss: 0.7824 - val_acc: 0.7188
# Epoch 80/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5101 - acc: 0.8204
# Epoch 00080: val_acc did not improve from 0.75000
# 71/71 [==============================] - 200s 3s/step - loss: 0.5101 - acc: 0.8204 - val_loss: 0.9012 - val_acc: 0.7098
# Epoch 81/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5210 - acc: 0.8253
# Epoch 00081: val_acc did not improve from 0.75000
# 71/71 [==============================] - 199s 3s/step - loss: 0.5210 - acc: 0.8253 - val_loss: 0.8261 - val_acc: 0.7500
# Epoch 82/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5582 - acc: 0.8093
# Epoch 00082: val_acc did not improve from 0.75000
# 71/71 [==============================] - 299s 4s/step - loss: 0.5582 - acc: 0.8093 - val_loss: 0.9125 - val_acc: 0.7009
# Epoch 83/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5509 - acc: 0.8160
# Epoch 00083: val_acc did not improve from 0.75000
# 71/71 [==============================] - 226s 3s/step - loss: 0.5509 - acc: 0.8160 - val_loss: 0.9153 - val_acc: 0.6741
# Epoch 84/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5220 - acc: 0.8186
# Epoch 00084: val_acc did not improve from 0.75000
# 71/71 [==============================] - 203s 3s/step - loss: 0.5220 - acc: 0.8186 - val_loss: 1.0090 - val_acc: 0.6562
# Epoch 85/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5527 - acc: 0.8115
# Epoch 00085: val_acc did not improve from 0.75000
# 71/71 [==============================] - 205s 3s/step - loss: 0.5527 - acc: 0.8115 - val_loss: 0.7859 - val_acc: 0.7054
# Epoch 86/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4885 - acc: 0.8249
# Epoch 00086: val_acc did not improve from 0.75000
# 71/71 [==============================] - 203s 3s/step - loss: 0.4885 - acc: 0.8249 - val_loss: 0.7635 - val_acc: 0.7232
# Epoch 87/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4578 - acc: 0.8369
# Epoch 00087: val_acc did not improve from 0.75000
# 71/71 [==============================] - 207s 3s/step - loss: 0.4578 - acc: 0.8369 - val_loss: 0.8188 - val_acc: 0.7188
# Epoch 88/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5020 - acc: 0.8235
# Epoch 00088: val_acc did not improve from 0.75000
# 71/71 [==============================] - 204s 3s/step - loss: 0.5020 - acc: 0.8235 - val_loss: 0.8375 - val_acc: 0.6830
# Epoch 89/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4745 - acc: 0.8329
# Epoch 00089: val_acc improved from 0.75000 to 0.75893, saving model to trained_model.h5
# 71/71 [==============================] - 205s 3s/step - loss: 0.4745 - acc: 0.8329 - val_loss: 0.8320 - val_acc: 0.7589
# Epoch 90/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4531 - acc: 0.8440
# Epoch 00090: val_acc did not improve from 0.75893
# 71/71 [==============================] - 205s 3s/step - loss: 0.4531 - acc: 0.8440 - val_loss: 0.9002 - val_acc: 0.6964
# Epoch 91/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5137 - acc: 0.8213
# Epoch 00091: val_acc did not improve from 0.75893
# 71/71 [==============================] - 206s 3s/step - loss: 0.5137 - acc: 0.8213 - val_loss: 0.9327 - val_acc: 0.7143
# Epoch 92/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4786 - acc: 0.8302
# Epoch 00092: val_acc did not improve from 0.75893
# 71/71 [==============================] - 204s 3s/step - loss: 0.4786 - acc: 0.8302 - val_loss: 0.8808 - val_acc: 0.7054
# Epoch 93/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4508 - acc: 0.8480
# Epoch 00093: val_acc did not improve from 0.75893
# 71/71 [==============================] - 202s 3s/step - loss: 0.4508 - acc: 0.8480 - val_loss: 0.9351 - val_acc: 0.7232
# Epoch 94/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4541 - acc: 0.8391
# Epoch 00094: val_acc did not improve from 0.75893
# 71/71 [==============================] - 251s 4s/step - loss: 0.4541 - acc: 0.8391 - val_loss: 0.7882 - val_acc: 0.7321
# Epoch 95/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4473 - acc: 0.8489
# Epoch 00095: val_acc did not improve from 0.75893
# 71/71 [==============================] - 206s 3s/step - loss: 0.4473 - acc: 0.8489 - val_loss: 0.8009 - val_acc: 0.7188
# Epoch 96/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4662 - acc: 0.8351
# Epoch 00096: val_acc did not improve from 0.75893
# 71/71 [==============================] - 207s 3s/step - loss: 0.4662 - acc: 0.8351 - val_loss: 0.9258 - val_acc: 0.7009
# Epoch 97/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4631 - acc: 0.8414
# Epoch 00097: val_acc did not improve from 0.75893
# 71/71 [==============================] - 207s 3s/step - loss: 0.4631 - acc: 0.8414 - val_loss: 1.6341 - val_acc: 0.5446
# Epoch 98/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5774 - acc: 0.8035
# Epoch 00098: val_acc did not improve from 0.75893
# 71/71 [==============================] - 204s 3s/step - loss: 0.5774 - acc: 0.8035 - val_loss: 0.8334 - val_acc: 0.7188
# Epoch 99/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4416 - acc: 0.8458
# Epoch 00099: val_acc did not improve from 0.75893
# 71/71 [==============================] - 207s 3s/step - loss: 0.4416 - acc: 0.8458 - val_loss: 0.8258 - val_acc: 0.7500
# Epoch 100/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4434 - acc: 0.8485
# Epoch 00100: val_acc improved from 0.75893 to 0.78571, saving model to trained_model.h5
# 71/71 [==============================] - 204s 3s/step - loss: 0.4434 - acc: 0.8485 - val_loss: 0.8008 - val_acc: 0.7857

# %%
from keras.preprocessing import image
import numpy as np
img_path = 'D:\\EDI_SDP\\Garbage classification\\Garbage classification\\paper\\paper4.jpg'

img = image.load_img(img_path, target_size=(300, 300))
img = image.img_to_array(img, dtype=np.uint8)
img=np.array(img)/255.0

plt.title("Loaded Image")
plt.axis('off')
plt.imshow(img.squeeze())

p=model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Maximum Probability: ",np.max(p[0], axis=-1))
predicted_class = labels[np.argmax(p[0], axis=-1)]
print("Classified:",predicted_class)
# Out:
# Maximum Probability:  0.9999503
# Classified: paper

# %%
classes=[]
prob=[]
print("\n-------------------Individual Probability--------------------------------\n")

for i,j in enumerate (p[0],0):
    print(labels[i].upper(),':',round(j*100,2),'%')
    classes.append(labels[i])
    prob.append(round(j*100,2))
    
def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(classes))
    plt.bar(index, prob)
    plt.xlabel('Labels', fontsize=12)
    plt.ylabel('Probability', fontsize=12)
    plt.xticks(index, classes, fontsize=12, rotation=20)
    plt.title('Probability for loaded image')
    plt.show()
plot_bar_x()
# Out:
# -------------------Individual Probability--------------------------------
#
# CARDBOARD : 0.0 %
# GLASS : 0.0 %
# METAL : 0.0 %
# PAPER : 100.0 %
# PLASTIC : 0.0 %
# TRASH : 0.0 %

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

# ________________ Graph 1 -------------------------

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

# ________________ Graph 2 -------------------------

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.show()

# %%
import tensorflow as tf
import keras
file = "Garbage.h5"
tflite_model = tf.keras.models.load_model(file)
#keras.models.save_model(model,file)
converter = tf.lite.TFLiteConverter.from_keras_model(tflite_model)
tflite_save=converter.convert()
open("garbage.tflite",'wb').write(tflite_save)
# Out:
# WARNING:tensorflow:From C:\Users\BHAKTI KARANGALE\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\BHAKTI KARANGALE\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: C:\Users\BHAKTI~1\AppData\Local\Temp\tmphp8jhy26\assets
# 11379700

# %%
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
img_path = 'D:\\EDI_SDP\\Garbage classification\\Garbage classification\\paper\\paper4.jpg'

img = image.load_img(img_path, target_size=(300, 300))
img = image.img_to_array(img, dtype=np.uint8)
img=np.array(img)/255.0

plt.title("Loaded Image")
plt.axis('off')
plt.imshow(img.squeeze())

p=model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Maximum Probability: ",np.max(p[0], axis=-1))
predicted_class = labels[np.argmax(p[0], axis=-1)]
print("Classified:",predicted_class)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b1c97a7ef5c7> in <module>
#      12 plt.imshow(img.squeeze())
#      13
# ---> 14 p=model.predict(img[np.newaxis, ...])
#      15
#      16 #print("Predicted shape",p.shape)
#
# NameError: name 'model' is not defined

# %%
classes=[]
prob=[]
print("\n-------------------Individual Probability--------------------------------\n")

for i,j in enumerate (p[0],0):
    print(labels[i].upper(),':',round(j*100,2),'%')
    classes.append(labels[i])
    prob.append(round(j*100,2))
    
def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(classes))
    plt.bar(index, prob)
    plt.xlabel('Labels', fontsize=12)
    plt.ylabel('Probability', fontsize=12)
    plt.xticks(index, classes, fontsize=12, rotation=20)
    plt.title('Probability for loaded image')
    plt.show()
plot_bar_x()
# Out:
# -------------------Individual Probability--------------------------------
#
# CARDBOARD : 0.15 %
# GLASS : 0.09 %
# METAL : 0.04 %
# PAPER : 98.09 %
# PLASTIC : 1.46 %
# TRASH : 0.16 %
